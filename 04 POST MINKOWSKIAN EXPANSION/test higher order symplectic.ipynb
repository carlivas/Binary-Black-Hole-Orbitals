# %% [markdown]
# # TB04 Test

# %%
# %run ./Functions_PM_higher_order_symplectic.ipynb

c = const.c.value
G = const.G.value
M_sun = const.M_sun.value
M_earth = const.M_earth.value

δ = np.math.pow(2.0, 1.0/3.0)
ruth4 = np.array([[0.5, 0.5*(1.0-δ), 0.5*(1.0-δ), 0.5],
                  [0.0,         1.0,          -δ, 1.0]]) / (2.0 - δ)
ruth3 = np.array([[2.0/3.0, -2.0/3.0, 1.0], [7.0/24.0, 0.75, -1.0/24.0]])
leap2 = np.array([[0.5, 0.5], [0.0, 1.0]])



m_1 = M_earth
m_2 = M_sun

R_S = 2*(m_1 + m_2)*G/c**2

x_1 = np.array([-152.100e9, 0])
x_2 = np.array([0.,         0])*R_S
v_1 = np.array([0.,   29.29e3])
v_2 = np.array([0.,         0])*c
s = x_1, x_2, v_1, v_2, m_1, m_2

t_max = 1e9
res = 1e4
dt = t_max/res


pos1, pos2, pos_CM = symplectic_integrate(s, t_max = t_max, dt = dt, coeffs=ruth4)

orbPlotter(pos1, pos2, pos_CM)

# %%
# %run ./Functions_PM_higher_order_symplectic.ipynb

c = const.c.value
G = const.G.value
M_sun = const.M_sun.value
M_earth = const.M_earth.value

δ = np.math.pow(2.0, 1.0/3.0)
ruth4 = np.array([[0.5, 0.5*(1.0-δ), 0.5*(1.0-δ), 0.5],
                  [0.0,         1.0,          -δ, 1.0]]) / (2.0 - δ)
ruth3 = np.array([[2.0/3.0, -2.0/3.0, 1.0], [7.0/24.0, 0.75, -1.0/24.0]])
leap2 = np.array([[0.5, 0.5], [0.0, 1.0]])



m_1 = 1e-4*M_sun
m_2 = M_sun

R_S = 2*(m_1 + m_2)*G/c**2

x_1 = np.array([1000, 10.])*R_S
x_2 = np.array([0.,   0.])*R_S
v_1 = np.array([0., 0.05])*c
v_2 = np.array([0.,    0])*c
s = x_1, x_2, v_1, v_2, m_1, m_2


t_max = 1e9
res = 1e4
dt = t_max/res


pos1, pos2, pos_CM = symplectic_integrate(s, t_max = t_max, dt = dt, coeffs=leap2)

orbPlotter(pos1, pos2, pos_CM)

# %%
pos1, pos2
# Out:
# (array([[2.95354540e+06, 2.95354071e+06, 2.95353116e+06, ...,
#          2.85496613e+06, 2.85495627e+06, 2.85494641e+06],
#         [2.95354540e+04, 1.49671491e+12, 2.99342847e+12, ...,
#          1.49626406e+16, 1.49641373e+16, 1.49656340e+16]]),
#  array([[0.00000000e+00, 4.69375356e-04, 1.42551034e-03, ...,
#          9.87023519e+00, 9.87122256e+00, 9.87220994e+00],
#         [0.00000000e+00, 3.00241220e+05, 6.00614649e+05, ...,
#          3.00334423e+09, 3.00364466e+09, 3.00394509e+09]]))

# %%
# %run ./Functions_PM_higher_order_symplectic.ipynb

c = const.c.value
G = const.G.value
M_sun = const.M_sun.value
M_earth = const.M_earth.value

δ = np.math.pow(2.0, 1.0/3.0)
ruth4 = np.array([[0.5, 0.5*(1.0-δ), 0.5*(1.0-δ), 0.5],
                  [0.0,         1.0,          -δ, 1.0]]) / (2.0 - δ)
ruth3 = np.array([[2.0/3.0, -2.0/3.0, 1.0], [7.0/24.0, 0.75, -1.0/24.0]])
leap2 = np.array([[0.5, 0.5], [0.0, 1.0]])



m_1 = M_earth
m_2 = M_sun

R_S = 2*(m_1 + m_2)*G/c**2

x_1 = np.array([-152.100e9, 0.])
x_2 = np.array([0.,   0.])
v_1 = rotate(np.array([0.,   29.29e3]),np.pi/3)
v_2 = np.array([0.,    0])
s = x_1, x_2, v_1, v_2, m_1, m_2


t_max = 1e9/3
res = 1e4
dt = t_max/res


pos1, pos2, pos_CM = symplectic_integrate(s, t_max = t_max, dt = dt, coeffs=ruth4)

orbPlotter(pos1, pos2, pos_CM)

# %%
x_1 = np.array([-152.100e9, 0.])
x_2 = np.array([0.,   0.])
v_1 = rotate(np.array([0.,   29.29e3]),np.pi/3)
v_2 = np.array([0.,    0])
s = x_1, x_2, v_1, v_2, m_1, m_2

t_max = 1e9/3
res = 1e4
dt = t_max/res


pos1, pos2, pos_CM = symplectic_integrate(s, t_max = t_max, dt = dt, coeffs=ruth3)

orbPlotter(pos1, pos2, pos_CM)
