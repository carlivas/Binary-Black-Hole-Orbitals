# %% [markdown]
# # (A) Dipping case

# %%
# This cell runs the file "Orbital_functions_n.ipynb" such that the functions in that file can be utillized here
# %run ./Orbital_functions_n.ipynb

# %%
#CM dipping
s1 = [10,0,0,0.08]
pos1 = orbitals(s1, t_max = 150, GR = False, dt=0.1)[0]
orbPlot1 = orbPlotter(pos1,'CM Dipping - Radial dip')

#CM dipping (with no stopping at RS) to check whether it's elliptical
s1 = [10,0,0,0.08]
pos1 = orbitals(s1, t_max = 150 ,RS = 0.0001, GR = False, dt=0.1)[0]
orbPlot1 = orbPlotter(pos1,'CM Dipping - Elliptical')

# #GR 
# s1 = [10,0,0,0.08]
# pos1 = orbitals(s1, GR = True)[0]
# orbPlot1 = orbPlotter(pos1,'GR Dipping - Radial dip', GR = True)
