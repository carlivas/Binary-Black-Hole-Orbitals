# %%
# This cell runs the file "Two_body_functions.ipynb" such that the functions in that file can be utillized here
# %run ./Two_body_functions.ipynb

# This cell runs the file "Orbital_functions_n.ipynb" such that the functions in that file can be utillized here
# %run ./Orbital_functions_n.ipynb

# %%
x_1 = np.array([0., 1000.])
x_2 = np.array([0.,-1000.])
v_1 = np.array([0.01, 0.0])
v_2 = np.array([-0.01,0.0])
a_1 = np.array([0.,    0.])
a_2 = np.array([0.,    0.])
m_1 = 1
m_2 = 1000

s = x_1, x_2, v_1, v_2, a_1, a_2, m_1, m_2

pos1, pos2, posCM, vel1, vel2, acc1, acc2 = twoOrbsEIH(s, t_max = 150000, dt = 1)
twoOrbPlotter(pos1, pos2, posCM, CM = True, filename='EIH3 CM_frame', save=False)


x_1 = np.array([0., 1000.])
x_2 = np.array([0.,-1000.])
v_1 = np.array([0.1, 0.0])
v_2 = np.array([-0.1,0.0])
a_1 = np.array([0.,    0.])
a_2 = np.array([0.,    0.])
m_1 = 1
m_2 = 1000

s = x_1, x_2, v_1, v_2, a_1, a_2, m_1, m_2

pos1, pos2, posCM, vel1, vel2, acc1, acc2 = twoOrbsNewt(s, t_max = 8000, dt = 1)
twoOrbPlotter(pos1, pos2, posCM, CM = True, filename='TB3 CM_frame', save=False)

# %%
x_1 = np.array([0., 69.8e9])
x_2 = np.array([0.,0.])
v_1 = np.array([38.86e3, 0.0])
v_2 = np.array([0.0, 0.0])
a_1 = np.array([0.,    0.])
a_2 = np.array([0.,    0.])
m_1 = 3.285e23
m_2 = 1.9891e30

s = x_1, x_2, v_1, v_2, a_1, a_2, m_1, m_2

pos1, pos2, posCM, vel1, vel2, acc1, acc2 = twoOrbsEIH(s, t_max = 1500000000, dt = 1000)
twoOrbPlotter(pos1, pos2, posCM, CM = True, filename='EIH3 CM_frame', save=False)

# %%
# pos1 = np.array(pos1)
# pos2 = np.array(pos2)
# vel1 = np.array(vel1)
# vel2 = np.array(vel2)

# x = (pos1[:,:] - pos2[:,:])
# v = (vel1[:,:] - vel2[:,:])


# s2 = [x[0,0], x[1,0], v[0,0], v[1,0]]
# pos = orbitals(s2, GR = True,t_max = 1160000,dt=1)[0]
# orbPlot = orbPlotter(pos,'E1', show = True, save = False)
