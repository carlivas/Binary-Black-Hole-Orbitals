# %%
# This cell runs the file "Two_body_functions.ipynb" such that the functions in that file can be utillized here
# %run ./Functions_SI.ipynb
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\IPython\core\magics\execution.py in run(self, parameter_s, runner, file_finder)
#     702             fpath = arg_lst[0]
# --> 703             filename = file_finder(fpath)
#     704         except IndexError:
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\IPython\utils\path.py in get_py_filename(name, force_win32)
#     108     else:
# --> 109         raise IOError('File `%r` not found.' % name)
#     110
#
# OSError: File `'./Functions_SI.ipynb.py'` not found.
#
# During handling of the above exception, another exception occurred:
#
# Exception                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_29760\1980772110.py in <module>
#       1 # This cell runs the file "Two_body_functions.ipynb" such that the functions in that file can be utillized here
# ----> 2 get_ipython().run_line_magic('run', './Functions_SI.ipynb')
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\IPython\core\interactiveshell.py in run_line_magic(self, magic_name, line, _stack_depth)
#    2346                 kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2347             with self.builtin_trap:
# -> 2348                 result = fn(*args, **kwargs)
#    2349             return result
#    2350
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\decorator.py in fun(*args, **kw)
#     230             if not kwsyntax:
#     231                 args, kw = fix(args, kw, sig)
# --> 232             return caller(func, *(extras + args), **kw)
#     233     fun.__name__ = func.__name__
#     234     fun.__doc__ = func.__doc__
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\IPython\core\magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\IPython\core\magics\execution.py in run(self, parameter_s, runner, file_finder)
#     712             if os.name == 'nt' and re.match(r"^'.*'$",fpath):
#     713                 warn('For Windows, use double quotes to wrap a filename: %run "mypath\\myfile.py"')
# --> 714             raise Exception(msg)
#     715         except TypeError:
#     716             if fpath in sys.meta_path:
#
# Exception: File `'./Functions_SI.ipynb.py'` not found.

# %%
m_1 = 10*c**2/G
m_2 = 15*c**2/G

x_1 = np.array([0., 1000.])
x_2 = np.array([0., -200.])
v_1 = np.array([0.005, 0.])*c
v_2 = np.array([-0.01, 0.])*c
# a_1 = np.array([0.,    0.])
# a_2 = np.array([0.,    0.])

s = x_1, x_2, v_1, v_2, m_1, m_2

pos1, pos2, pos_CM = run_model(s, t_max = 30000/c, dt = 0.1/c, EIH = False)

twoOrbPlotter(pos1, pos2, pos_CM, CM=True, filename='TB04 CM_frame_SI')

# # Change to CM frame
# pos1 = pos1 - pos_CM
# pos2 = pos2 - pos_CM
# pos_CM = np.array([0,0])

# fig, ax = plt.subplots(figsize=(14,14))
# ax.plot(pos1[0], pos1[1], label = 'pos1')
# ax.plot(pos2[0], pos2[1], label = 'pos2')
# ax.plot(pos_CM[0], pos_CM[1], label = 'posCM')
# xlim, ylim = plotLimsTwoBody(pos1, pos2)
# ax.set_xlim(xlim)
# ax.set_ylim(ylim)
# ax.set_aspect('1')
# ax.legend()
# fig.tight_layout()

# %%
m_1 = 10*c**2/G
x_1 = np.array([500., 1000.])
v_1 = np.array([-0.01,  0. ])*c
a_1 = np.array([0.,     0. ])

m_2 = 10*c**2/G
x_2 = np.array([0., -1000.])
v_2 = np.array([0.01,  0. ])*c
a_2 = np.array([0.,     0.])

s = x_1, x_2, v_1, v_2, m_1, m_2

pos1, pos2, pos_CM = run_model(s, t_max = 500000/c, dt=1/c, EIH = False)

twoOrbPlotter(pos1, pos2, pos_CM, CM=True, filename='TB02 CM_frame_SI')

# # Change to CM frame
# pos1 = pos1 - pos_CM
# pos2 = pos2 - pos_CM
# pos_CM = np.array([0,0])

# fig, ax = plt.subplots(figsize=(14,14))
# ax.plot(pos1[0], pos1[1], label = 'pos1')
# ax.plot(pos2[0], pos2[1], label = 'pos2')
# ax.plot(pos_CM[0], pos_CM[1], label = 'posCM')
# xlim, ylim = plotLimsTwoBody(pos1, pos2)
# ax.set_xlim(xlim)
# ax.set_ylim(ylim)
# ax.set_aspect('1')
# ax.legend()
# fig.tight_layout()

# %%
m_1 = 10*c**2/G
x_1 = np.array([500., 1000.])
v_1 = np.array([0.025, 0.])*c

m_2 = 10*c**2/G
x_2 = np.array([0.,-1000.])
v_2 = np.array([0.01, 0.])*c

s = x_1, x_2, v_1, v_2, m_1, m_2

pos1, pos2, pos_CM= run_model(s, t_max=300000/c, dt=1/c, EIH = False)

twoOrbPlotter(pos1, pos2, pos_CM, CM=False, filename='TB03 rest_frame')
twoOrbPlotter(pos1, pos2, pos_CM, CM=True, filename='TB03 CM_frame')

# %% [markdown]
# # TWO BODY PROBLEM EIH (SI UNITS)

# %%
# This cell runs the file "Two_body_functions.ipynb" such that the functions in that file can be utillized here
# %run ./Orbital_functions_SI.ipynb
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\IPython\core\magics\execution.py in run(self, parameter_s, runner, file_finder)
#     702             fpath = arg_lst[0]
# --> 703             filename = file_finder(fpath)
#     704         except IndexError:
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\IPython\utils\path.py in get_py_filename(name, force_win32)
#     108     else:
# --> 109         raise IOError('File `%r` not found.' % name)
#     110
#
# OSError: File `'./Orbital_functions_SI.ipynb.py'` not found.
#
# During handling of the above exception, another exception occurred:
#
# Exception                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_41784\3828113406.py in <module>
#       1 # This cell runs the file "Two_body_functions.ipynb" such that the functions in that file can be utillized here
# ----> 2 get_ipython().run_line_magic('run', './Orbital_functions_SI.ipynb')
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\IPython\core\interactiveshell.py in run_line_magic(self, magic_name, line, _stack_depth)
#    2346                 kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2347             with self.builtin_trap:
# -> 2348                 result = fn(*args, **kwargs)
#    2349             return result
#    2350
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\decorator.py in fun(*args, **kw)
#     230             if not kwsyntax:
#     231                 args, kw = fix(args, kw, sig)
# --> 232             return caller(func, *(extras + args), **kw)
#     233     fun.__name__ = func.__name__
#     234     fun.__doc__ = func.__doc__
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\IPython\core\magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\IPython\core\magics\execution.py in run(self, parameter_s, runner, file_finder)
#     712             if os.name == 'nt' and re.match(r"^'.*'$",fpath):
#     713                 warn('For Windows, use double quotes to wrap a filename: %run "mypath\\myfile.py"')
# --> 714             raise Exception(msg)
#     715         except TypeError:
#     716             if fpath in sys.meta_path:
#
# Exception: File `'./Orbital_functions_SI.ipynb.py'` not found.

# %%
x_1 = np.array([0., 1000.])
x_2 = np.array([0.,-1000.])
v_1 = np.array([0.01,  0.])*c
v_2 = np.array([-0.01, 0.])*c
a_1 = np.array([0.,    0.])
a_2 = np.array([0.,    0.])
m_1 = 10*c**2/G
m_2 = 15*c**2/G

s = x_1, x_2, v_1, v_2, m_1, m_2

pos1, pos2, pos_CM = run_model(s, t_max = 500000/c, dt = 1/c, EIH = True)

twoOrbPlotter(pos1, pos2, pos_CM, CM=True, filename='EIH1 CM_frame')

# %%
m_1 = 1*c**2/G
m_2 = 1000*c**2/G

R_S = 2 * (m_1 + m_2)*G/c**2
R_S
# Out:
# 2001.9999999999998

# %%
x_1 = np.array([0., 1000.])
x_2 = np.array([0.,-1000.])
v_1 = np.array([0.1,  -0.01])*c
v_2 = np.array([-0.05, 0.05])*c
a_1 = np.array([0.,    0.])
a_2 = np.array([0.,    0.])
m_1 = 1*c**2/G
m_2 = 1000*c**2/G

s = x_1, x_2, v_1, v_2, m_1, m_2

pos1, pos2, pos_CM = run_model(s, t_max=150000/c, dt=1/c, EIH=True)

twoOrbPlotter(pos1, pos2, pos_CM, CM = True, filename='EIH3 CM_frame')
